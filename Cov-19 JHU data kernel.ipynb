# %%
# Data from JHU at https://github.com/CSSEGISandData/COVID-19
# Referencing two kaggle notebooks:
# (1) https://www.kaggle.com/hotstaff/2019-ncov-cases-global-map-use-github
# (2) https://www.kaggle.com/hotstaff/covid-19-dataset-automatic-generation

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import glob

# %%
# !git clone https://github.com/CSSEGISandData/COVID-19.git
# Out:
# Cloning into 'COVID-19'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 1308 (delta 32), reused 31 (delta 15), pack-reused 1256
# Receiving objects: 100% (1308/1308), 30.21 MiB | 34.36 MiB/s, done.
# Resolving deltas: 100% (776/776), done.

# %%
dailyfiles = sorted(glob.glob('COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/*.csv'))

# %%
dailyfiles
# Out:
# ['COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-22-2020.csv',
#  'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-23-2020.csv',
#  'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-24-2020.csv',
#  'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-25-2020.csv',
#  'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-26-2020.csv',
#  'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-27-2020.csv',
#  'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-28-2020.csv',
#  'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-29-2020.csv',
#  'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-30-2020.csv',
#  'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-31-2020.csv',
#  'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-01-2020.csv',
#  'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-02-2020.csv',
# ...

# %%
df = pd.concat([pd.read_csv(file) for file in dailyfiles])

# %%
df
# Out:
#                            Province/State  Country/Region  \
# 0                                   Anhui  Mainland China
# 1                                 Beijing  Mainland China
# 2                               Chongqing  Mainland China
# 3                                  Fujian  Mainland China
# 4                                   Gansu  Mainland China
# ..                                    ...             ...
# 100                           Seattle, WA              US
# 101                             Tempe, AZ              US
# 102  Lackland, TX (From Diamond Princess)              US
# 103     Omaha, NE (From Diamond Princess)              US
# 104    Travis, CA (From Diamond Princess)              US
#
#              Last Update  Confirmed  Deaths  Recovered
# 0        1/22/2020 17:00        1.0     NaN        NaN
# 1        1/22/2020 17:00       14.0     NaN        NaN
# 2        1/22/2020 17:00        6.0     NaN        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2585 entries, 0 to 104
# Data columns (total 6 columns):
# Province/State    1838 non-null object
# Country/Region    2585 non-null object
# Last Update       2585 non-null object
# Confirmed         2566 non-null float64
# Deaths            2144 non-null float64
# Recovered         2197 non-null float64
# dtypes: float64(3), object(3)
# memory usage: 141.4+ KB

# %%
df["Province/State"].unique()
# Out:
# array(['Anhui', 'Beijing', 'Chongqing', 'Fujian', 'Gansu', 'Guangdong',
#        'Guangxi', 'Guizhou', 'Hainan', 'Hebei', 'Heilongjiang', 'Henan',
#        'Hong Kong', 'Hubei', 'Hunan', 'Inner Mongolia', 'Jiangsu',
#        'Jiangxi', 'Jilin', 'Liaoning', 'Macau', 'Ningxia', 'Qinghai',
#        'Shaanxi', 'Shandong', 'Shanghai', 'Shanxi', 'Sichuan', 'Taiwan',
#        'Tianjin', 'Tibet', 'Washington', 'Xinjiang', 'Yunnan', 'Zhejiang',
#        nan, 'Chicago', 'Illinois', 'California', 'Arizona', 'Ontario',
#        'New South Wales', 'Victoria', 'British Columbia', 'Bavaria',
#        'Queensland', 'Chicago, IL', 'South Australia', 'Boston, MA',
#        'Los Angeles, CA', 'Orange, CA', 'Santa Clara, CA', 'Seattle, WA',
#        'Tempe, AZ', 'San Benito, CA', 'Toronto, ON', 'London, ON',
#        'Madison, WI', 'Cruise Ship', 'Diamond Princess cruise ship',
#        'San Diego County, CA', 'San Antonio, TX', 'Ashland, NE',
# ...

# %%
df["Country/Region"].unique()
# Out:
# array(['Mainland China', 'Hong Kong', 'Macau', 'Taiwan', 'US', 'Japan',
#        'Thailand', 'South Korea', 'Singapore', 'Philippines', 'Malaysia',
#        'Vietnam', 'Australia', 'Mexico', 'Brazil', 'Colombia', 'France',
#        'Nepal', 'Canada', 'Cambodia', 'Sri Lanka', 'Ivory Coast',
#        'Germany', 'Finland', 'United Arab Emirates', 'India', 'Italy',
#        'UK', 'Russia', 'Sweden', 'Spain', 'Belgium', 'Others', 'Egypt',
#        'Iran', 'Israel', 'Lebanon', 'Iraq', 'Oman', 'Afghanistan',
#        'Bahrain', 'Kuwait', 'Austria', 'Algeria', 'Croatia',
#        'Switzerland', 'Pakistan', 'Georgia', 'Greece', 'North Macedonia',
#        'Norway', 'Romania', 'Denmark', 'Estonia', 'Netherlands',
#        'San Marino'], dtype=object)

# %%
len(df["Country/Region"].unique())

# %%
# fill NaN
df = df.fillna({"Province/State": 'None'})

# Change astype
df["Last Update"] = pd.to_datetime(df["Last Update"])
df["Confirmed"] = df["Confirmed"].fillna(0).astype('int')
df["Deaths"] = df["Deaths"].fillna(0).astype('int')
df["Recovered"] =df["Recovered"].fillna(0).astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2585 entries, 0 to 104
# Data columns (total 6 columns):
# Province/State    2585 non-null object
# Country/Region    2585 non-null object
# Last Update       2585 non-null datetime64[ns]
# Confirmed         2585 non-null int64
# Deaths            2585 non-null int64
# Recovered         2585 non-null int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 141.4+ KB

# %%
sorted(df["Last Update"].unique())
# Out:
# [numpy.datetime64('2020-01-22T17:00:00.000000000'),
#  numpy.datetime64('2020-01-23T17:00:00.000000000'),
#  numpy.datetime64('2020-01-24T17:00:00.000000000'),
#  numpy.datetime64('2020-01-25T17:00:00.000000000'),
#  numpy.datetime64('2020-01-26T16:00:00.000000000'),
#  numpy.datetime64('2020-01-27T23:59:00.000000000'),
#  numpy.datetime64('2020-01-28T23:00:00.000000000'),
#  numpy.datetime64('2020-01-29T19:30:00.000000000'),
#  numpy.datetime64('2020-01-30T16:00:00.000000000'),
#  numpy.datetime64('2020-01-31T08:15:00.000000000'),
#  numpy.datetime64('2020-01-31T08:15:53.000000000'),
#  numpy.datetime64('2020-01-31T10:37:00.000000000'),
#  numpy.datetime64('2020-01-31T15:20:00.000000000'),
#  numpy.datetime64('2020-01-31T15:20:56.000000000'),
#  numpy.datetime64('2020-01-31T16:13:00.000000000'),
#  numpy.datetime64('2020-01-31T16:13:45.000000000'),
#  numpy.datetime64('2020-01-31T23:59:00.000000000'),
#  numpy.datetime64('2020-02-01T01:52:00.000000000'),
# ...

# %%
uniquets=sorted(df["Last Update"].unique())
print(f"Last Updated:{uniquets[-1]}")
# Out:
# Last Updated:2020-02-27T23:33:02.000000000
